# %% [markdown]
# # VacationPy
#
# ---

# %%
# Dependencies and Setup

import hvplot.pandas
import pandas as pd
import requests
import geoviews as gv
import plotly.express as px

# Import API key

from api_keys import geoapify_key

# %%
city_data_df=pd.read_csv("C:/Users/uzmaf/OneDrive/Desktop/challenges/python-api-challenge/WeatherPy/cities.csv")
city_data_df.head()
# Out:
#    City_ID        City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0    waitangi -43.9535 -176.5597     13.79        86         100
# 1        1      newman  37.3138 -121.0208     38.19        37          46
# 2        2       utrik  11.2278  169.8474     28.51        75         100
# 3        3  bairnsdale -37.8333  147.6167     12.25        82           3
# 4        4   grytviken -54.2811  -36.5092     -2.66        91         100
#
#    Wind Speed Country        Date
# 0        4.47      NZ  1690937897
# 1        0.89      US  1690937897
# 2        7.04      MH  1690937897
# 3        0.81      AU  1690937608
# 4        2.28      GS  1690937898

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display
# city_data_df.hvplot.points(geo=True, color='red', alpha=0.2,
#                        xlim=(-180, -30), ylim=(0, 72), tiles='ESRI')

# %%
ideal_humdity=city_data_df[city_data_df["Humidity"] <= 60]

# %%
px.scatter_geo(ideal_humdity, lat="Lat", lon="Lng",color="Humidity")
# Out:
# <div>                            <div id="76cdae0e-955d-4607-b7be-a2940f14d0e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76cdae0e-955d-4607-b7be-a2940f14d0e4")) {                    Plotly.newPlot(                        "76cdae0e-955d-4607-b7be-a2940f14d0e4",                        [{"geo":"geo","hovertemplate":"Lat=%{lat}<br>Lng=%{lon}<br>Humidity=%{marker.color}<extra></extra>","lat":[37.3138,-25.066,-6.3383,64.5667,68.0546,42.097,-11.0483,-10.6681,27.5219,60.7161,66.4167,-27.6082,69.4865,52.2667,63.7553,62.456,31.6804,22.7187,-32.25,14.7308,46.9531,52.35,57.79,-20.9319,64.8569,39.1834,-25.3,38.7621,38.5196,64.8,53.75,-28.8667,22.785,45.5234,22.5667,-6.4667,35.2937,38.7839,41.2668,62.6667,-20.4089,18.05,53.0675,63.2842,-22.9575,49.4169,-3.
# ...
